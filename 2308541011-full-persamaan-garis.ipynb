# %%
import numpy as np
import matplotlib.pyplot as plt
#Menggunakan \n1\n2\n3, untuk memudahkan pengguna membaca pilihan yang disediakan
print("Terdapat 3 kasus, yaitu\n1.Kasus pertama, diketahui 4 buah titik\n2.Kasus kedua, diketahui gradien dan sebuah titik\n3.Kasus ketiga, diketahui persamaan garis yang memenuhi ax+by=c")
pilihan_11 = float(input("Masukkan kasus yang ingin anda pecahkan ="))
print("=====================================================================================================")

if pilihan_11 == 1:
    print("Anda memilih kasus 1, baiklah!")
    print("Pertama-tama masukkan titik-titik A,B,C,D yang diketahui")
    ax_11 = float(input("Masukkan nilai x pertama dari garis pertama ="))
    ay_11 = float(input("Masukkan nilai y pertama dari garis pertama ="))
    bx_11 = float(input("Masukkan nilai x kedua dari garis pertama ="))
    by_11 = float(input("Masukkan nilai y kedua dari garis pertama ="))
    print("Selanjutnya masukkan nilai x dan y untuk garis kedua")
    cx_11 = float(input("Masukkan nilai x pertama dari garis kedua ="))
    cy_11 = float(input("Masukkan nilai y pertama dari garis kedua ="))
    dx_11 = float(input("Masukkan nilai x kedua dari garis kedua ="))
    dy_11 = float(input("Masukkan nilai y kedua dari garis kedua ="))
    
    #Selanjutnya akan dihitung gradien pertama dan kedua dengan rumus y2-y1/x2-x1
    m1_11 = (by_11-ay_11)/(bx_11-ax_11)
    m2_11 = (dy_11-cy_11)/(dx_11-cx_11)
    
    #Lalu akan mencari titik potong pertama dan kedua terhadap sumbu y 
    tp1_11 = -m1_11*ax_11+ay_11
    tp2_11 = -m2_11*cx_11+cy_11
    
    print("Dari titik-titik A dan B yang diketahui, didapatkan persamaan garis pertama, yaitu y={}x+{}".format(m1_11,tp1_11))
    print("Dari titik-titik C dan D yang diketahui, didapatkan persamaan garis pertama, yaitu y={}x+{}".format(m2_11,tp2_11))

    #Lalu kita membuat semua kemungkinan yang akan terjadi
    if m1_11==m2_11:
        print("=====================================================================================================")
        print("Wah! Gradien pertama dan kedua hasilnya sama nih, jadi kedua garis akan sejajar, lalu kemungkinan solusinya akan berjumlah tak terhingga")
        if tp1_11==tp2_11:
            print("=====================================================================================================")
            print("Waduu, ternyata persamaan garisnya juga sama, hal ini menyebabkan kedua garis berhhimpitan sehingga solusinya juga akan tak berhingga banyaknya!")
            x_11=np.linspace(tp1_11-5,tp1_11+5,100)
            plt.plot(x_11,m1_11*(x-ax_11)+ay_11,color='purple')
            plt.plot(x_11,m2_11*(x-cx_11)+cy_11,color='red')
            plt.axvline(x=0,color='grey')
            pltaxhline(y=0,color='grey')
        else:
            print("=====================================================================================================")
            ("Hasil dari kedua garis tidak terdapat penyelesaian karena tidak mungkin berpotongan")
            x_11=np.linspace(tp1_11-5,tp1_11+5,100)
            plt.plot(x_11,m1_11*(x-ax_11)+ay_11,color='blue')
            plt.plot(x_11,m2_11*(x-cx_11)+cy_11,color='yellow')
            plt.axvline(x=0,color='grey')
            plt.axhline(y=0,color='grey')
            plt.show()
    else:
        print("=====================================================================================================")
        print("Akan terdapat satu titik potong")
        #Membuat program untuk menentukan titik potong
        tp_x11 = (-m2_11*cx_11+cy_11+m1_11*ax_11-ay_11)/(m1_11-m2_11)
        tp_y11 = m1_11*(tp_x11-ax_11)+ay_11
        print("=====================================================================================================")
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x11,tp_y11))
    
        x=np.linspace(tp_x11-5,tp_x11+5,100)
        plt.plot(x,m1_11*(x-ax_11)+ay_11,color='green',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m1_11,ax_11,ay_11))
        plt.plot(x,m2_11*(x-cx_11)+cy_11,color='blue',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m1_11,cx_11,cy_11))
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.plot(tp_x11,tp_y11,color='yellow',marker='o',markersize=4)
        plt.title('Grafik persamaan garis')
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.legend(loc='best')
        plt.show()
        
elif pilihan_11==2:
    print("Baiklah, kamu memilih kasus 2 untuk dipecahkan!")
    print("Pada kasus dua ini, diketahui nilai gradien dan dua titik A dan B")
    m1_11 = float(input("Pertama-tama, masukkan nilai Gradien dari garis pertama yang diketahui ="))
    ax_11 = float(input("Lalu masukkan nilai x dari titik yang dilewati oleh garis pertama adalah ="))
    ay_11 = float(input("Kemudian masukkan nilai y dari titik yang dilewati oleh garis pertama adalah ="))
    print("Dari titik tersebut, diperoleh persamaan garis pertama, yaitu y={}(x-{})+{}".format(m1_11,ax_11,ay_11))
    print("=====================================================================================================")
    
    m2_11 = float(input("Lalu masukkan nilai Gradien dari garis kedua yang diketahui ="))
    bx_11 = float(input("Lalu masukkan nilai x dari titik yang dilewati oleh garis kedua adalah ="))
    by_11 = float(input("kemudian masukkan nilai y dari titik yang dilewati oleh garis kedua adalah ="))
    print("Dari titik tersebut, diperoleh persamaan garis kedua, yaitu y={}(x+{})+{}".format(m2_11,bx_11,by_11))
    print("=====================================================================================================")
    
    #Kemudian membuat program untuk menghitung persamaan garis
    c1_11 = -m1_11*ax_11+ay_11
    c2_11 = -m2_11*bx_11+by_11
    
    if m1_11==m2_11:
        print("=====================================================================================================")
        print("Ternyata, hasil garis dari gradien dan dua titik tersebut adalah garis sejajar")
        if c1_11==c2_11:
            print("=====================================================================================================")
            print("Ternyata, hasil garis dari gradien dan dua titik tersebut memiliki solusi yang tak berhingga")
        else:
            print("=====================================================================================================")
            print("Ternyata, hasil garis dari gradien dan dua titik tersebut tidak memiliki solusi")
    else:
        print("=====================================================================================================")
        print("Ternyata, hasil garis dari gradien dan dua titik tersebut adalah garis yang akan berpotongan di satu titik")
        #Menentukan titik potong
        tpx_11 = (-m2_11*bx_11+by_11+m1_11*ax_11-ay_11)/(m1_11-m2_11)
        tpy_11 = m1_11*(tpx_11-ax_11)+ay_11
        print("=====================================================================================================")
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tpx_11,tpy_11))
        
        x=np.linspace(tpx_11-5,tpx_11+5,100)
        plt.plot(x,m1_11*(x-ax_11)+ay_11,color='green',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m1_11,ax_11,ay_11))
        plt.plot(x,m2_11*(x-bx_11)+by_11,color='blue',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m1_11,bx_11,by_11))
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.plot(tpx_11,tpy_11,color='yellow',marker='o',markersize=4)
        plt.title('Grafik persamaan garis')
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.legend(loc='best')
        plt.show()
        
elif pilihan_11==3:
    print("Kamu memilih kasus 3 untuk dipecahkan, baiklah!")
    print("Pada kasus 3 ini, diketahui dua buah persamaan garis, lalu program akan menentukan apakah garis itu sejajar, berhimpitan atau berpotongan")
    print("Pada kasus ini, akan dibutuhkan garis yang memenuhi persamaan berbentuk ax=by=c dan dx+ey=f.")
    a1_11 = float(input("Pertama-tama masukkan koefisien dari x pada garis pertama ="))
    a2_11 = float(input("Lalu masukkan koefisien dari y pada garis pertama ="))
    C1_11 = float(input("Kemudian masukkan konstanta dari garis pertama ="))
    
    b1_11=float(input("Kita lanjut untuk memasukkan koefisien dari x pada garis kedua ="))
    b2_11 = float(input("Kemudian masukkan koefisien dari y pada garis kedua ="))
    C2_11 = float(input("Terakhir, masukkan konstanta dari garis kedua ="))
    
    #Membuat program untuk menghitung gradien dari persamaan garis pertama dan kedua
    m1_11 = (-a1_11)/a2_11
    m2_11 = (-b1_11)/b2_11
    
    #Kemudian membuat program untuk menentukan garis potong
    Ca_11 = C1_11/a2_11
    Cb_11 = C2_11/b2_11
    
    #Lalu membuat program untuk semua kemungkinan
    if m1_11==m2_11:
        print("=====================================================================================================")
        print("Ternyata hasil dari kedua persamaan garis itu akan menghasilkan garis sejajar")
        x_11=np.linspace(-5,5,100)
        plt.plot(x_11,m2_11*(x-b1_11)+b2_11,color='purple')
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.show()
        if c1_11==c2_11:
            print("=====================================================================================================")
            print("Ternyata hasil dari kedua persamaan garis itu akan menghasilkan garis yang berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("=====================================================================================================")
            print("Ternyata hasil dari kedua persamaan garis itu akan menghasilkan garis yang sejajar")
    else:
        print("=====================================================================================================")
        print("Hasil dari kedua persamaan garis akan memiliki satu titik potong")
        #Menentukan titik potong
        tpx_11 = (-m2_11*b1_11+b2_11+m1_11*a1_11-a2_11)/(m1_11-m2_11)
        tpy_11 = m1_11*(tpx_11-a1_11)+a2_11
        print("=====================================================================================================")
        print("Titik potong kedua garis adalag ({:.3f},{:.3f})".format(tpx_11,tpy_11))
        
        x_11=np.linspace(tpx_11-5,tpx_11+5,100)
        plt.plot(x_11,m1_11*(x-a1_11)+a2_11,color='red',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m1_11,a1_11,a2_11))
        plt.plot(x_11,m2_11*(x-b1_11)+b2_11,color='blue',label="y={:.3f}(x-{:.3f})+{:.3f}".format(m1_11,b1_11,b2_11))
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.plot(tpx_11,tpy_11,color='purple',marker='o',markersize=4)
        plt.title('Grafik persamaan garis')
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.legend(loc='best')
        plt.show()
# Out:
# Terdapat 3 kasus, yaitu
# 1.Kasus pertama, diketahui 4 buah titik
# 2.Kasus kedua, diketahui gradien dan sebuah titik
# 3.Kasus ketiga, diketahui persamaan garis yang memenuhi ax+by=c
# Masukkan kasus yang ingin anda pecahkan = 2
# ...
# Baiklah, kamu memilih kasus 2 untuk dipecahkan!
# Pada kasus dua ini, diketahui nilai gradien dan dua titik A dan B
# Pertama-tama, masukkan nilai Gradien dari garis pertama yang diketahui = 2
# Lalu masukkan nilai x dari titik yang dilewati oleh garis pertama adalah = 1
# Kemudian masukkan nilai y dari titik yang dilewati oleh garis pertama adalah = 3
# Dari titik tersebut, diperoleh persamaan garis pertama, yaitu y=2.0(x-1.0)+3.0
# ...
# Lalu masukkan nilai Gradien dari garis kedua yang diketahui = 3
# Lalu masukkan nilai x dari titik yang dilewati oleh garis kedua adalah = 2
# kemudian masukkan nilai y dari titik yang dilewati oleh garis kedua adalah = 3
# Dari titik tersebut, diperoleh persamaan garis kedua, yaitu y=3.0(x+2.0)+3.0
# ...
