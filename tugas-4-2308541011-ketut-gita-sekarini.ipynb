# %%
##2.12

Bahan = ['Telur', 'Tomat', 'Air', 'MSG', 'Lada']
print(Bahan)
# Out:
# ['Telur', 'Tomat', 'Air', 'MSG', 'Lada']

# %%
print(Bahan[3])
# Out:
# MSG

# %%
print(Bahan[-4])
# Out:
# Tomat

# %%
Bahan[1] = 'Kangkung'
print(Bahan)
# Out:
# ['Telur', 'Kangkung', 'Air', 'MSG', 'Lada']

# %%
print(Bahan[2:4])
# Out:
# ['Air', 'MSG']

# %%
##2.13

nama = ['Gita', 'Maysya', 'Nariska', 'Dyas', 'Atik']
nama.append('Ica')
print(nama)
# Out:
# ['Gita', 'Maysya', 'Nariska', 'Dyas', 'Atik', 'Ica']

# %%
nama.insert(3,'Dewi')
print(nama)
# Out:
# ['Gita', 'Maysya', 'Nariska', 'Dewi', 'Dyas', 'Atik', 'Ica']

# %%
nama.remove('Ica')
print(nama)
# Out:
# ['Gita', 'Maysya', 'Nariska', 'Dewi', 'Dyas', 'Atik']

# %%
print('Ica' in nama)
# Out:
# False

# %%
print(len(nama))
# Out:
# 6

# %%
##2.14

Red_Team = ['Tony', 'Natasha', 'Vision', 'Peter', 'Rodey']
for jenis in Red_Team:
    print(jenis)
# Out:
# Tony
# Natasha
# Vision
# Peter
# Rodey

# %%
i = 0
while i < len(Red_Team):
    print(Red_Team[i])
    i+=2
# Out:
# Tony
# Vision
# Rodey
