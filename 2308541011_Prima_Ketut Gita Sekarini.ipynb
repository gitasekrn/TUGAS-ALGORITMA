# %%
print("Soal:")
print("Jika diketahui n adalah dua digit terakhir NIM kalian, maka tentukan bilangan prima antara 1000n dan 1000(n+1)")
print("========================================================(11)==========================================================")
#Masukkan nilai n sesuai dua digit terakhir nim
n_11 = 11
#Atur rentang sesuai dengan arahan yang diberikan
dari_11 = 1000*G_11
hingga_11 = 1000*(G_11+1)

#Lalu menggunakan fungsi dan parameter (def)
def prima_11(a_11):
    if a_11 <= 1:
        return False
    for b_11 in range (2, int(a_11**0.5)+1):
        if a_11 % b_11 == 0:
            return False
    return True 
#Karena jika angka kurang dari sama dengan satu maka dapat dipastikan angka tsb bukanlah bil prima
#Dan jika angka tersebut habis dibagi dengan angka yang bukan satu dan dirinya sendiri maka dapat dipastikan juga bukan merupakan bil prima

print(f'Anggota bilangan prima diantara {dari_11} dan {hingga_11} adalah')

#Dibuat untuk menyimpan bilangan prima yang diketahui dalam rentang tersebut agar tersusun 
AnggotaPrima_11 = []

for a_11 in range (dari_11, hingga_11 + 1):
    if prima_11(a_11):
        AnggotaPrima_11.append(a_11)
        
print(AnggotaPrima_11)
print("!!!Terima Kasih!!!")
# Out:
# Soal:
# Jika diketahui n adalah dua digit terakhir NIM kalian, maka tentukan bilangan prima antara 1000n dan 1000(n+1)
# ========================================================(11)==========================================================
# Anggota bilangan prima diantara 11000 dan 12000 adalah
# ...
