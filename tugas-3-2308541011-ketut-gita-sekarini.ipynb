# %%
##
# 2.10
Bensin = input("Bensin apa yang ingin anda beli?")
if Bensin == 'pertamax':
    Nominal = input("Masukkan nominal anda Rp. ")
    Liter = int(Nominal) // int(13200)
if Bensin == 'pertalite':
    Nominal = input("Masukkan nominal anda Rp. ")
    Liter = int(Nominal) // int(10000)
if Bensin == 'pertamax turbo':
    Nominal = input("Masukkan nominal anda Rp. ")
    Liter = int(Nominal) // int(14400)
if Bensin == 'dexlite':
    Nominal = input("Masukkan nominal anda Rp. ")
    Liter = int(Nominal) // int(14550)
if Bensin == 'pertamina dex':
    Nominal = input("Masukkan nominal anda Rp. ")
    Liter = int(Nominal) // int(15100)
print(f"Anda membeli total sekitar {Liter} liter {Bensin}")
# Out:
# Bensin apa yang ingin anda beli? pertamax
# Masukkan nominal anda Rp.  30000
# Anda membeli total sekitar 2 liter pertamax

# %%
##
# 2.11
x = int(input("masukkan x <= 100 :"))
while x <= 100 :
    if x%2 == 0 :
        print(f"{x} adalah bilangan genap")
    else :
        print(f"{x} adalah bilangan ganjil")
    x += 15
# Out:
# masukkan x <= 100 : 25
# 25 adalah bilangan ganjil
# 40 adalah bilangan genap
# 55 adalah bilangan ganjil
# 70 adalah bilangan genap
# 85 adalah bilangan ganjil
# 100 adalah bilangan genap
